# %% [markdown]
# # Scraping Google Playstore Reviews of GCash

# %% [markdown]
# * reference = https://python.plainenglish.io/scraping-storing-google-play-app-reviews-with-python-5640c933c476
# * app url = https://play.google.com/store/apps/details?id=com.globe.gcash.android&hl=en&gl=US
# * app id = com.globe.gcash.android

# %% [markdown]
# #### Importing necessary libraries

# %%
#Imports

import pandas as pd
from google_play_scraper import app, Sort, reviews

from pprint import pprint

# for storing in MongoDB
import pymongo
from pymongo import MongoClient

# for keeping track of timing
import datetime as dt
from tzlocal import get_localzone


# for building in wait times
import random
import time

# %% [markdown]
# #### Setting up Mongo DB tables
#
# MongoDB creates databases and collections lazily. This means these things won’t actually exist until we start inserting documents (essentially the MongoDB equivalent to the rows of relational database tables) into our collections.
#
# This code block sets up the Mongo Client, creatse a new database for our project, and sets up new collections (essentially the MongoDB equivalent to the tables of relational databases). We’ll store app info in one collection and app reviews in another.

# %%
## Set up Mongo client
client = MongoClient(host='localhost', port=27017)

## Database for project
gcash_reviews_db = client['gcash_reviews_db']

## Set up new collection within project db for app info
info_collection = gcash_reviews_db['info_collection']

## Set up new collection within project db for app reviews
review_collection = gcash_reviews_db['review_collection']

# %% [markdown]
# #### Setting up App Scraping

# %%
app_names = ['GCash']
app_ids = ['com.globe.gcash.android']

# %%
## Loop through app IDs to get app info
app_info = []
for i in app_ids:
    info = app(i)
    del info['comments']
    app_info.append(info)

## Pretty print the data for the first app
pprint(app_info[0])
# Out:
# {'adSupported': None,
#  'androidVersion': '4.4',
#  'androidVersionText': '4.4 and up',
#  'appId': 'com.globe.gcash.android',
#  'containsAds': False,
#  'contentRating': 'Everyone',
#  'contentRatingDescription': None,
#  'currency': 'USD',
#  'description': 'A mobile wallet app that lets you instantly pay bills, buy '
#                 'load, send money, shop, and more – all in the safety of your '
#                 'own home!\r\n'
#                 '\r\n'
#                 "Enjoy fast and easy payments with GCash! It's a safe, secure "
#                 'mobile wallet that connects to your mobile number, making it '
#                 'available anytime, anywhere. Download GCash today so you can '
#                 'complete your errands without having to break quarantine!\r\n'
#                 '\r\n'
#                 '• Open to all networks\r\n'
#                 '• Zero-rated for Globe and TM\r\n'
#                 '• Regulated by BSP\r\n'
#                 '\r\n'
#                 '<b>SEND MONEY IN REAL TIME</b>\r\n'
#                 '• Send money to GCash, Coins.ph, and PayMaya users\r\n'
#                 '• Send any amount to multiple people at once with Ang Pao\r\n'
#                 '\r\n'
#                 '<b>TRANSFER MONEY TO 40+ BANKS INSTANTLY</b>\r\n'
#                 '• Transfer funds instantly to any major bank account '
#                 'nationwide\r\n'
#                 '• Save bank account details for future fund transfers\r\n'
#                 '• Send to BPI, BDO, Metrobank, Landbank, Unionbank, '
#                 'Chinabank, etc\r\n'
#                 '\r\n'
#                 '<b>PAY BILLS AND FEES TO 400+ BILLERS</b>\r\n'
#                 '• Pay utility bills and more without going out\r\n'
#                 '• Past due bills and paying with GCredit also accepted\r\n'
#                 '• Save favorite billers and set payment reminders\r\n'
#                 '• Electricity: Meralco, Kuryente Load, and other provincial '
#                 'providers\r\n'
#                 '• Water: Manila Water, Maynilad, and other provincial '
#                 'providers\r\n'
#                 '• Cable, Internet: Globe at Home, Sky Broadband, Smart Bro, '
#                 'etc\r\n'
#                 '• Telecoms: Globe Postpaid, PLDT DSL, Smart, Sun Cellular, '
#                 'etc\r\n'
#                 '• Credit Cards, Loans: BPI, BDO, Citibank, Home Credit, '
#                 'U-Peso, etc\r\n'
#                 '• Government: BIR, DFA, MMDA, NBI, SSS, Pag IBIG, etc\r\n'
#                 '• Travel: AirAsia, Cebu Pacific, PAL, etc\r\n'
#                 '\r\n'
#                 '<b>BUY LOAD ANYTIME, ANYWHERE</b>\r\n'
#                 '• Buy load for anyone on all networks instantly\r\n'
#                 '• Load any Globe, TM, Smart, TNT, Sun Cellular number\r\n'
#                 '• Buy exclusive Globe and TM load combos\r\n'
#                 '• Buy broadband packages for Globe at Home Prepaid Wifi\r\n'
#                 '• Buy TV channels, PIN for Cignal and SkyCable\r\n'
#                 '• Buy MaxiCare prepaid health insurance\r\n'
#                 '\r\n'
#                 '<b>RECEIVE REMITTANCES AND PAYPAL FUNDS ONLINE</b>\r\n'
#                 '• Receive remittances from MoneyGram and Western Union while '
#                 'at home\r\n'
#                 '• Key in your reference number and receive money on your '
#                 'phone\r\n'
#                 '• Link your Paypal to GCash to withdraw or transfer funds for '
#                 'free\r\n'
#                 '\r\n'
#                 '<b>EXTEND YOUR BUDGET WITH GCREDIT</b>\r\n'
#                 "• Gain access to GCredit, GCash's mobile credit line, based "
#                 'on your GScore\r\n'
#                 '• Credit limit starts from P1,000 to P30,000\r\n'
#                 '• Build your GScore by using GCash frequently\r\n'
#                 '\r\n'
#                 '<b>CASH-IN WITH ONLINE BANKING AND DEBIT CARDS</b>\r\n'
#                 '• Top up your GCash using online banking: BPI, RCBC, '
#                 'Unionbank, etc\r\n'
#                 '• Mastercard/Visa debit card also available: BDO, AUB, Citi, '
#                 'HSBC, and more\r\n'
#                 '• Cash in over the counter: Cebuana Lhuillier, Villarica, '
#                 'Touchpay, Bayad Center, etc\r\n'
#                 '\r\n'
#                 '<b>SHOP ONLINE EVEN WITH NO CREDIT CARD</b>\r\n'
#                 '• Easy, secure, and instant payments to Lazada, Shopee, and '
#                 'more\r\n'
#                 '• Pay for food and grocery deliveries with American Express '
#                 'Virtual Pay or GCash Mastercard\r\n'
#                 '• Link your GCash to App Store and Play Store to pay for '
#                 'apps, games, movies, and more\r\n'
#                 '\r\n'
#                 '<b>PAY QR AT OVER 70,000 PARTNERS</b>\r\n'
#                 '• Scan to pay QR codes at over 70,000 GCash partners\r\n'
#                 '• Pay at Puregold, SM, and a ton of shops and restaurants '
#                 'nationwide\r\n'
#                 '\r\n'
#                 '<b>BUY GAMING CREDITS INSTANTLY</b>\r\n'
#                 '• Buy 10 kinds of gaming pins from top brands at Php 1=1 '
#                 'cost\r\n'
#                 '• Get Garena Shells, Steam Wallet Codes, LevelUp, Blizzard, '
#                 'Ragnarok, GameClub Credits\r\n'
#                 '• Razer Gold, Rules of Survival, Mobile Legends Diamonds, '
#                 'PUBG PINs available\r\n'
#                 '\r\n'
#                 '<b>OPEN A SAVINGS ACCOUNT WITH NO INITIAL DEPOSIT</b>\r\n'
#                 '• No minimum deposit, no minimum balance\r\n'
#                 '• Up to 4.1% interest rate per annum\r\n'
#                 '• In partnership with CIMB Bank; insured by PDIC\r\n'
#                 '\r\n'
#                 '<b>INVEST MONEY FOR AS LOW AS P50</b>\r\n'
#                 '• Subscribe to an investment fund for as low as P50\r\n'
#                 '• In partnership with ATRAM Trust Corp\r\n'
#                 '\r\n'
#                 '<b>HELP RESTORE PHILIPPINE FORESTS WITH GCASH FOREST</b>\r\n'
#                 '• Earn green energy on GCash Forest by doing green '
#                 'activities\r\n'
#                 '• Green activities: Walking, completing cashless transactions '
#                 'on GCash\r\n'
#                 '• Get enough points to plant a tree at Ipo Watershed\r\n'
#                 '\r\n'
#                 'Join our ongoing promos to get freebies! Get cashbacks, '
#                 'vouchers, discounts, or even treats from Jollibee, Lazada, '
#                 'Bonchon and more!\r\n'
#                 '\r\n'
#                 'Now with 20 million users!',
#  'descriptionHTML': 'A mobile wallet app that lets you instantly pay bills, '
#                     'buy load, send money, shop, and more – all in the safety '
#                     'of your own home!<br><br>Enjoy fast and easy payments '
#                     'with GCash! It&#39;s a safe, secure mobile wallet that '
#                     'connects to your mobile number, making it available '
#                     'anytime, anywhere. Download GCash today so you can '
#                     'complete your errands without having to break '
#                     'quarantine!<br><br>• Open to all networks<br>• Zero-rated '
#                     'for Globe and TM<br>• Regulated by BSP<br><br><b>SEND '
#                     'MONEY IN REAL TIME</b><br>• Send money to GCash, '
#                     'Coins.ph, and PayMaya users<br>• Send any amount to '
#                     'multiple people at once with Ang Pao<br><br><b>TRANSFER '
#                     'MONEY TO 40+ BANKS INSTANTLY</b><br>• Transfer funds '
#                     'instantly to any major bank account nationwide<br>• Save '
#                     'bank account details for future fund transfers<br>• Send '
#                     'to BPI, BDO, Metrobank, Landbank, Unionbank, Chinabank, '
#                     'etc<br><br><b>PAY BILLS AND FEES TO 400+ BILLERS</b><br>• '
#                     'Pay utility bills and more without going out<br>• Past '
#                     'due bills and paying with GCredit also accepted<br>• Save '
#                     'favorite billers and set payment reminders<br>• '
#                     'Electricity: Meralco, Kuryente Load, and other provincial '
#                     'providers<br>• Water: Manila Water, Maynilad, and other '
#                     'provincial providers<br>• Cable, Internet: Globe at Home, '
#                     'Sky Broadband, Smart Bro, etc<br>• Telecoms: Globe '
#                     'Postpaid, PLDT DSL, Smart, Sun Cellular, etc<br>• Credit '
#                     'Cards, Loans: BPI, BDO, Citibank, Home Credit, U-Peso, '
#                     'etc<br>• Government: BIR, DFA, MMDA, NBI, SSS, Pag IBIG, '
#                     'etc<br>• Travel: AirAsia, Cebu Pacific, PAL, '
#                     'etc<br><br><b>BUY LOAD ANYTIME, ANYWHERE</b><br>• Buy '
#                     'load for anyone on all networks instantly<br>• Load any '
#                     'Globe, TM, Smart, TNT, Sun Cellular number<br>• Buy '
#                     'exclusive Globe and TM load combos<br>• Buy broadband '
#                     'packages for Globe at Home Prepaid Wifi<br>• Buy TV '
#                     'channels, PIN for Cignal and SkyCable<br>• Buy MaxiCare '
#                     'prepaid health insurance<br><br><b>RECEIVE REMITTANCES '
#                     'AND PAYPAL FUNDS ONLINE</b><br>• Receive remittances from '
#                     'MoneyGram and Western Union while at home<br>• Key in '
#                     'your reference number and receive money on your '
#                     'phone<br>• Link your Paypal to GCash to withdraw or '
#                     'transfer funds for free<br><br><b>EXTEND YOUR BUDGET WITH '
#                     'GCREDIT</b><br>• Gain access to GCredit, GCash&#39;s '
#                     'mobile credit line, based on your GScore<br>• Credit '
#                     'limit starts from P1,000 to P30,000<br>• Build your '
#                     'GScore by using GCash frequently<br><br><b>CASH-IN WITH '
#                     'ONLINE BANKING AND DEBIT CARDS</b><br>• Top up your GCash '
#                     'using online banking: BPI, RCBC, Unionbank, etc<br>• '
#                     'Mastercard/Visa debit card also available: BDO, AUB, '
#                     'Citi, HSBC, and more<br>• Cash in over the counter: '
#                     'Cebuana Lhuillier, Villarica, Touchpay, Bayad Center, '
#                     'etc<br><br><b>SHOP ONLINE EVEN WITH NO CREDIT '
#                     'CARD</b><br>• Easy, secure, and instant payments to '
#                     'Lazada, Shopee, and more<br>• Pay for food and grocery '
#                     'deliveries with American Express Virtual Pay or GCash '
#                     'Mastercard<br>• Link your GCash to App Store and Play '
#                     'Store to pay for apps, games, movies, and '
#                     'more<br><br><b>PAY QR AT OVER 70,000 PARTNERS</b><br>• '
#                     'Scan to pay QR codes at over 70,000 GCash partners<br>• '
#                     'Pay at Puregold, SM, and a ton of shops and restaurants '
#                     'nationwide<br><br><b>BUY GAMING CREDITS '
#                     'INSTANTLY</b><br>• Buy 10 kinds of gaming pins from top '
#                     'brands at Php 1=1 cost<br>• Get Garena Shells, Steam '
#                     'Wallet Codes, LevelUp, Blizzard, Ragnarok, GameClub '
#                     'Credits<br>• Razer Gold, Rules of Survival, Mobile '
#                     'Legends Diamonds, PUBG PINs available<br><br><b>OPEN A '
#                     'SAVINGS ACCOUNT WITH NO INITIAL DEPOSIT</b><br>• No '
#                     'minimum deposit, no minimum balance<br>• Up to 4.1% '
#                     'interest rate per annum<br>• In partnership with CIMB '
#                     'Bank; insured by PDIC<br><br><b>INVEST MONEY FOR AS LOW '
#                     'AS P50</b><br>• Subscribe to an investment fund for as '
#                     'low as P50<br>• In partnership with ATRAM Trust '
#                     'Corp<br><br><b>HELP RESTORE PHILIPPINE FORESTS WITH GCASH '
#                     'FOREST</b><br>• Earn green energy on GCash Forest by '
#                     'doing green activities<br>• Green activities: Walking, '
#                     'completing cashless transactions on GCash<br>• Get enough '
#                     'points to plant a tree at Ipo Watershed<br><br>Join our '
#                     'ongoing promos to get freebies! Get cashbacks, vouchers, '
#                     'discounts, or even treats from Jollibee, Lazada, Bonchon '
#                     'and more!<br><br>Now with 20 million users!',
#  'developer': 'Mynt - Globe Fintech Innovations',
#  'developerAddress': None,
#  'developerEmail': 'support@gcash.com',
#  'developerId': 'Mynt+-+Globe+Fintech+Innovations',
#  'developerInternalID': '5955884870415406672',
#  'developerWebsite': 'https://www.gcash.com',
#  'editorsChoice': False,
#  'free': True,
#  'genre': 'Finance',
#  'genreId': 'FINANCE',
#  'headerImage': 'https://play-lh.googleusercontent.com/5a1kOcUgIYQykhlXL4nqpEd6X2l0VcVGlUh-tznEU30QQJZqPKvTmbdjP4b3FEtSepDj',
#  'histogram': [52160, 12520, 27349, 50385, 412036],
#  'icon': 'https://play-lh.googleusercontent.com/QNP0Aj2hyumAmYiWVAsJtY2LLTQnzHxdW7-DpwFUFNkPJjgRxi-BXg7A4yI6tgYKMeU',
#  'inAppProductPrice': None,
#  'installs': '10,000,000+',
#  'minInstalls': 10000000,
#  'offersIAP': False,
#  'originalPrice': None,
#  'price': 0,
#  'privacyPolicy': 'http://www.gcash.com/privacy-notice/20190402/',
#  'ratings': 554450,
#  'recentChanges': 'Getting around the GCash app is now easier! We’ve added a '
#                   'navigation bar to help make your cashless transactions more '
#                   'convenient.\r\n'
#                   '\r\n'
#                   'We’ve also upgraded your GLife experience with categories, '
#                   'making it easier for you to find your favorite merchants. '
#                   'Explore new merchants like ConcepStore, Globe Online Shop, '
#                   'and more with GLife!\r\n'
#                   '\r\n'
#                   'More billers are now available! Pay your ANTECO and Asian '
#                   'Vision Cable bills on GCash without leaving your home. '
#                   '#KayaMoGCashMo',
#  'recentChangesHTML': 'Getting around the GCash app is now easier! We’ve added '
#                       'a navigation bar to help make your cashless '
#                       'transactions more convenient.<br><br>We’ve also '
#                       'upgraded your GLife experience with categories, making '
#                       'it easier for you to find your favorite merchants. '
#                       'Explore new merchants like ConcepStore, Globe Online '
#                       'Shop, and more with GLife!<br><br>More billers are now '
#                       'available! Pay your ANTECO and Asian Vision Cable bills '
#                       'on GCash without leaving your home. #KayaMoGCashMo',
#  'released': 'Mar 23, 2012',
#  'reviews': 199593,
#  'sale': False,
#  'saleText': None,
#  'saleTime': None,
#  'score': 4.3664246,
#  'screenshots': ['https://play-lh.googleusercontent.com/wbP9zRg8yb93M1NfgR8oqzmIfHj5ZPaGV-UNZ-3s4hCekuHrLb68sKrALlsf2fNnzTGc',
#                  'https://play-lh.googleusercontent.com/69kFlsPmEIrLM2vVOXGGH-5jmtr2p-NY2RlVBHthUHxD1OEBNzG3UqVe-ppoN8sMB0U',
#                  'https://play-lh.googleusercontent.com/Eb6_RHQ8GT1aPVk_uwSROlF7q6bToNzwkjL4OkDeguFswhsceoaRVRJ8_7RndClDbGs',
#                  'https://play-lh.googleusercontent.com/qfiwd4dQyUuqoe0iyAQP8y8poezBNBjnqSKK0pDWOZZVRU3cP5jlUgS3zxYoiTBfrQ',
#                  'https://play-lh.googleusercontent.com/IB5lIUrdIe9V2vchtN3vb3XfVVhboN3bTGxb-yKo78RciCbLmKzu8yBWzmrsUSWh3A',
#                  'https://play-lh.googleusercontent.com/PV30C1V3P-B-X04QyEis3HtFTYxva8Lu231z1oDPn5fIMaQC9UuZ1SUHZkJanwwfsA',
#                  'https://play-lh.googleusercontent.com/EDBmKKqHVZQ0rc-Ef8m5Z1drYv0ETFlJCXuKIB0ozdOVJ5ACL5uvPh1wFTVBe2zMBAo'],
#  'size': '58M',
#  'summary': 'A mobile wallet that lets you shop, send, save, and more with '
#             'your smartphone!',
#  'summaryHTML': 'A mobile wallet that lets you shop, send, save, and more with '
#                 'your smartphone!',
#  'title': 'GCash - Buy Load, Pay Bills, Send Money',
#  'updated': 1621925171,
#  'url': 'https://play.google.com/store/apps/details?id=com.globe.gcash.android&hl=en&gl=us',
#  'version': '5.41.0',
#  'video': 'https://www.youtube.com/embed/oK5WL4-4Z9U?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#  'videoImage': 'https://i.ytimg.com/vi/oK5WL4-4Z9U/hqdefault.jpg'}

# %%
## Insert app details into info_collection
info_collection.insert_many(app_info)

# %%
## Query the collection and create DataFrame from the list of dicts
info_df = pd.DataFrame(list(info_collection.find({})))
info_df.head()
# Out:
#                         _id                                    title  \
# 0  60b75decc5eccca0e375ce54  GCash - Buy Load, Pay Bills, Send Money
#
#                                          description  \
# 0  A mobile wallet app that lets you instantly pa...
#
#                                      descriptionHTML  \
# 0  A mobile wallet app that lets you instantly pa...
#
#                                              summary  \
# 0  A mobile wallet that lets you shop, send, save...
#
#                                          summaryHTML     installs  \
# 0  A mobile wallet that lets you shop, send, save...  10,000,000+
#
#    minInstalls     score  ratings  ...  adSupported containsAds      released  \
# 0     10000000  4.366425   554450  ...         None       False  Mar 23, 2012
#
#       updated version                                      recentChanges  \
# 0  1621925171  5.41.0  Getting around the GCash app is now easier! We...
#
#                                    recentChangesHTML editorsChoice  \
# 0  Getting around the GCash app is now easier! We...         False
#
#                      appId                                                url
# 0  com.globe.gcash.android  https://play.google.com/store/apps/details?id=...
#
# [1 rows x 50 columns]

# %% [markdown]
# ## Scraping App Reviews

# %%
## Loop through apps to get reviews
for app_name, app_id in zip(app_names, app_ids):
    
    # Get start time
    start = dt.datetime.now(tz=get_localzone())
    fmt= "%m/%d/%y - %T %p"    
    
    # Print starting output for app
    print('---'*20)
    print('---'*20)    
    print(f'***** {app_name} started at {start.strftime(fmt)}')
    print()
    
    # Empty list for storing reviews
    app_reviews = []
    
    # Number of reviews to scrape per batch
    count = 200
    
    # To keep track of how many batches have been completed
    batch_num = 0
    
    
    # Retrieve reviews (and continuation_token) with reviews function
    rvws, token = reviews(
        app_id,           # found in app's url
        lang='en',        # defaults to 'en'
        country='us',     # defaults to 'us'
        sort=Sort.NEWEST, # start with most recent
        count=count       # batch size
    )
    
    
    # For each review obtained
    for r in rvws:
        r['app_name'] = app_name # add key for app's name
        r['app_id'] = app_id     # add key for app's id
     
    
    # Add the list of review dicts to overall list
    app_reviews.extend(rvws)
    
    # Increase batch count by one
    batch_num +=1 
    print(f'Batch {batch_num} completed.')
    
    # Wait 1 to 5 seconds to start next batch
    time.sleep(random.randint(3,5))
    
    
    
    # Append review IDs to list prior to starting next batch
    pre_review_ids = []
    for rvw in app_reviews:
        pre_review_ids.append(rvw['reviewId'])
    
    
    # Loop through at most max number of batches
    for batch in range(4999):
        rvws, token = reviews( # store continuation_token
            app_id,
            lang='en',
            country='us',
            sort=Sort.NEWEST,
            count=count,
            # using token obtained from previous batch
            continuation_token=token
        )
        
        # Append unique review IDs from current batch to new list
        new_review_ids = []
        for r in rvws:
            new_review_ids.append(r['reviewId'])
            
            # And add keys for name and id to ea review dict
            r['app_name'] = app_name # add key for app's name
            r['app_id'] = app_id     # add key for app's id
     
        # Add the list of review dicts to main app_reviews list
        app_reviews.extend(rvws)
        
        # Increase batch count by one
        batch_num +=1
        
        # Break loop and stop scraping for current app if most recent batch
          # did not add any unique reviews
        all_review_ids = pre_review_ids + new_review_ids
        if len(set(pre_review_ids)) == len(set(all_review_ids)):
            print(f'No reviews left to scrape. Completed {batch_num} batches.\n')
            break
        
        # all_review_ids becomes pre_review_ids to check against 
          # for next batch
        pre_review_ids = all_review_ids
        
        
        # At every 100th batch
        if batch_num%100==0:
            
            # print update on number of batches
            print(f'Batch {batch_num} completed.')
            
            # insert reviews into collection
            review_collection.insert_many(app_reviews)
            
            # print update about num reviews inserted
            store_time = dt.datetime.now(tz=get_localzone())
            print(f"""
            Successfully inserted {len(app_reviews)} {app_name} 
            reviews into collection at {store_time.strftime(fmt)}.\n
            """)
            
            # empty our list for next round of 100 batches
            app_reviews = []
        
        # Wait 1 to 5 seconds to start next batch
        time.sleep(random.randint(3,5))
      
    
    # Print update when max number of batches has been reached
      # OR when last batch didn't add any unique reviews
    print(f'Done scraping {app_name}.')
    print(f'Scraped a total of {len(set(pre_review_ids))} unique reviews.\n')
    
    
    # Insert remaining reviews into collection
    review_collection.insert_many(app_reviews)
    
    # Get end time
    end = dt.datetime.now(tz=get_localzone())
    
    # Print ending output for app
    print(f"""
    Successfully inserted all {app_name} reviews into collection
    at {end.strftime(fmt)}.\n
    """)
    print(f'Time elapsed for {app_name}: {end-start}')
    print('---'*20)
    print('---'*20)
    print('\n')
    
    # Wait 1 to 5 seconds to start scraping next app
    time.sleep(random.randint(1,5))
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** GCash started at 06/02/21 - 18:36:12 PM
#
# Batch 1 completed.
# Batch 100 completed.
#
#             Successfully inserted 20000 GCash
#             reviews into collection at 06/02/21 - 18:44:25 PM.
#
#
# Batch 200 completed.
#
#             Successfully inserted 20000 GCash
#             reviews into collection at 06/02/21 - 18:52:49 PM.
#
#
# Batch 300 completed.
#
#             Successfully inserted 20000 GCash
#             reviews into collection at 06/02/21 - 19:01:38 PM.
#
#
# Batch 400 completed.
#
#             Successfully inserted 20000 GCash
#             reviews into collection at 06/02/21 - 19:09:56 PM.
#
#
# Batch 500 completed.
#
#             Successfully inserted 20000 GCash
#             reviews into collection at 06/02/21 - 19:18:32 PM.
#
#
# Batch 600 completed.
#
#             Successfully inserted 20000 GCash
#             reviews into collection at 06/02/21 - 19:27:09 PM.
#
#
# Batch 700 completed.
#
#             Successfully inserted 20000 GCash
#             reviews into collection at 06/02/21 - 19:35:35 PM.
#
#
# Batch 800 completed.
#
#             Successfully inserted 20000 GCash
#             reviews into collection at 06/02/21 - 19:44:28 PM.
#
#
# Batch 900 completed.
#
#             Successfully inserted 20000 GCash
#             reviews into collection at 06/02/21 - 19:53:24 PM.
#
#
# No reviews left to scrape. Completed 997 batches.
#
# Done scraping GCash.
# Scraped a total of 198936 unique reviews.
#
#
#     Successfully inserted all GCash reviews into collection
#     at 06/02/21 - 20:01:55 PM.
#
#
# Time elapsed for GCash: 1:25:42.829913
# ------------------------------------------------------------
# ------------------------------------------------------------

# %%
len(app_reviews)
# Out:
# 6600

# %%
app_reviews[3]
# Out:
# {'reviewId': 'gp:AOqpTOFGVLBuwumsJtFw91d8J4zVPx7oNpGHosC2NFSNUeRmypleYbvPSVOPu8CpAx6trlYJxEBI4cXNJH0aAQ',
#  'userName': 'Irma Reyes',
#  'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwm4GG5mzMbxFW7rW-naTjloLqSb8_QkKMwHdQ0=mo',
#  'content': 'Relevant',
#  'score': 5,
#  'thumbsUpCount': 0,
#  'reviewCreatedVersion': '5.40.0',
#  'at': datetime.datetime(2021, 6, 2, 16, 12, 30),
#  'replyContent': None,
#  'repliedAt': None,
#  'app_name': 'GCash',
#  'app_id': 'com.globe.gcash.android'}

# %%
review_df = pd.DataFrame(list(review_collection.find({})))
review_df.head()

# remove ids
# split date column 
# ask for release dates ng software then tag

# least priority -> tag what language the reviews are
# Out:
#                         _id  \
# 0  60b76108c5eccca0e375ce55
# 1  60b76108c5eccca0e375ce56
# 2  60b76108c5eccca0e375ce57
# 3  60b76108c5eccca0e375ce58
# 4  60b76108c5eccca0e375ce59
#
#                                             reviewId             userName  \
# 0  gp:AOqpTOHa4x04QC93zb0pxQZ-1Q1GwFeysD-XpcDTW78...  Emmanuel Jim Roldan
# 1  gp:AOqpTOFOvZwSS0iVvmGbcBKkwFyprROh5KqfcJuI5jg...         Harem Tuazon
# 2  gp:AOqpTOFb35bOoUsvlsEEPVO0UrtxJ2fut8jq5sdiexC...        Fraxilyn Nael
# 3  gp:AOqpTOFRgY4C4LVX_-Cr5D1zxW881WGrlPf01jMWwr4...   Mary rose Manipolo
# 4  gp:AOqpTOH8Znzr1cV9K-1A9ci8IBaQOr-fUkvUhC4P7ZU...        Ferritch Vlog
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AATXAJ...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a-/AOh14...
# 3  https://play-lh.googleusercontent.com/a-/AOh14...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0                      Good for mobile online deals.      1              0
# 1  Ilang beses nang naulit na nag load ako nag ba...      1              0
# 2              Its a great experience and convenient      4              0
# 3  Ok na ok sya para sa mga easy transaction lalo...      5              0
# 4                         very helpful and contented      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt app_name  \
# 0               5.40.0 2021-06-02 18:32:37         None       NaT    GCash
# 1               5.41.0 2021-06-02 18:32:14         None       NaT    GCash
# 2               5.40.0 2021-06-02 18:32:07         None       NaT    GCash
# 3               5.41.0 2021-06-02 18:31:31         None       NaT    GCash
# 4               5.40.0 2021-06-02 18:31:25         None       NaT    GCash
#
#                     app_id
# 0  com.globe.gcash.android
# 1  com.globe.gcash.android
# 2  com.globe.gcash.android
# 3  com.globe.gcash.android
# 4  com.globe.gcash.android

# %%
review_df.shape
# Out:
# (199298, 13)

# %%
review_df.to_csv('gcash_reviews_playstore.csv')

# %%
review_df.columns
# Out:
# Index(['_id', 'reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'app_name', 'app_id'],
#       dtype='object')

# %%
review_df.sort_values(by=['at']).head(30)
# Out:
#                              _id  \
# 198697  60b77333c5eccca0e378d67e
# 198696  60b77333c5eccca0e378d67d
# 198695  60b77333c5eccca0e378d67c
# 198694  60b77333c5eccca0e378d67b
# 198693  60b77333c5eccca0e378d67a
# 198692  60b77333c5eccca0e378d679
# 198691  60b77333c5eccca0e378d678
# 198690  60b77333c5eccca0e378d677
# 198689  60b77333c5eccca0e378d676
# 198688  60b77333c5eccca0e378d675
# 198687  60b77333c5eccca0e378d674
# 198686  60b77333c5eccca0e378d673
# 198685  60b77333c5eccca0e378d672
# 198684  60b77333c5eccca0e378d671
# 198683  60b77333c5eccca0e378d670
# 198682  60b77333c5eccca0e378d66f
# 198681  60b77333c5eccca0e378d66e
# 198680  60b77333c5eccca0e378d66d
# 198679  60b77333c5eccca0e378d66c
# 198678  60b77333c5eccca0e378d66b
# 198677  60b77333c5eccca0e378d66a
# 198676  60b77333c5eccca0e378d669
# 198675  60b77333c5eccca0e378d668
# 198674  60b77333c5eccca0e378d667
# 198673  60b77333c5eccca0e378d666
# 198672  60b77333c5eccca0e378d665
# 198671  60b77333c5eccca0e378d664
# 198670  60b77333c5eccca0e378d663
# 198669  60b77333c5eccca0e378d662
# 198668  60b77333c5eccca0e378d661
#
#                                                  reviewId  \
# 198697  lg:AOqpTOEuRDzBAl8r4_kyXgkmLFXU0n51uFDExjDgogL...
# 198696  lg:AOqpTOEtSVLgUNG0zDOcuKw30rV9L22JYj_0luEr52-...
# 198695  lg:AOqpTOHtVCRQ280_md40DmafRCh73olr3srKIPr2UV6...
# 198694  lg:AOqpTOEfo_fYQ8nkv3Rm0ST063JhAUsdnucRkmUR2XO...
# 198693  lg:AOqpTOFFSwUPBt4vUzDjb_A0tpfUPkQmXFc8YZmHUeC...
# 198692  lg:AOqpTOEqa8V0KOvOM57V83v8t1BmodlxwEReZOjNfmP...
# 198691  lg:AOqpTOGmQzUEyeSopSDKec2h1sR2_rzLAcweOxs3Ag_...
# 198690  lg:AOqpTOEIFp10kTGbXQvLlgkWAEfIIPzEQ4sUTQG1TDx...
# 198689  lg:AOqpTOHM_26Wt43A1_4pAuvUKrhrhiAU32BoNMaRi30...
# 198688  lg:AOqpTOHN7S4eUAmawWt1MB7SESCeQJQpR5BYV5sJ-Vk...
# 198687  lg:AOqpTOE8n2MROwDp__tvYEhJ5j8GIygK9bsMPy_MCN0...
# 198686  lg:AOqpTOE92pZxK6cfEWU6H4ZWYtKK5OFlbm2JkoqNVg2...
# 198685  lg:AOqpTOHdQzHUjFVZJH6xYY9ZlsQBcfcslc8yYyAHRIN...
# 198684  lg:AOqpTOGFQOOikZt2RcZ1R5WEjcl0K5yL7eJFJyX54zf...
# 198683  lg:AOqpTOFwxj3uR5ucQttZwx-yomlu0_du1_0AryKXiJ4...
# 198682  lg:AOqpTOEv9_qYfH3a8AEESrjSrbVC8seFqgfQerQ_nNH...
# 198681  lg:AOqpTOEm_PLslJhlnpICb0yZRQyY-kujTh1yrhRRURu...
# 198680  lg:AOqpTOF7A05bPc1GB74fScEyC9qWMtusZwBeKx2ceV_...
# 198679  lg:AOqpTOF6HC007Ii36Mq0pgd3m3516cQNpdO2nBbCMvz...
# 198678  lg:AOqpTOFtM_Lqbg97QSCoQq0rnoI5oFWUjlZAE8_oLTw...
# 198677  lg:AOqpTOHG2roOYG8TIeZTdS7SsbL-Ds9byEmWgLPg0Ho...
# 198676  lg:AOqpTOGE0zNgXEU8_pBPXBQqUfYz7vg-g79bc-BnMjS...
# 198675  lg:AOqpTOH_s3Oj5KoEMxf-l4efdMq5u4dxgdjxCETpxKG...
# 198674  gp:AOqpTOFCrD4WOrnSR3H39hoqM2lPMeaP5wi-hlqEwuY...
# 198673  gp:AOqpTOF8dRkG7_vypK62txkKylNbukGqhYpdgqi9m_X...
# 198672  gp:AOqpTOEdI7-vQlI_RjEP2Q7fKHQq8AeBmfIwdvgBZ2X...
# 198671  gp:AOqpTOFA6WBxtveEHpbgWdFLIgEPCtuoOZOYxRrINGf...
# 198670  gp:AOqpTOGm4kHNIRp1Aev-Dum-1dsmCcguaFcKnqamFlF...
# 198669  gp:AOqpTOElJIvpunF8iHJ-_EC3_Z6i0ElOFKVTWl9hrIw...
# 198668  gp:AOqpTOGgc00q2KKqdA-LdUXms2G-LNtzOgFiC8g7wrx...
#
#                     userName  \
# 198697         A Google user
# 198696         A Google user
# 198695         A Google user
# 198694         A Google user
# 198693         A Google user
# 198692         A Google user
# 198691         A Google user
# 198690         A Google user
# 198689         A Google user
# 198688         A Google user
# 198687         A Google user
# 198686         A Google user
# 198685         A Google user
# 198684         A Google user
# 198683         A Google user
# 198682         A Google user
# 198681         A Google user
# 198680         A Google user
# 198679         A Google user
# 198678         A Google user
# 198677         A Google user
# 198676         A Google user
# 198675         A Google user
# 198674  Nathanne Ralph Hayag
# 198673          saman saadat
# 198672          Doe Rodillas
# 198671                Wyne D
# 198670            bojo perez
# 198669                 J Yap
# 198668         Vienne Yellow
#
#                                                 userImage  \
# 198697  https://play-lh.googleusercontent.com/EGemoI2N...
# 198696  https://play-lh.googleusercontent.com/EGemoI2N...
# 198695  https://play-lh.googleusercontent.com/EGemoI2N...
# 198694  https://play-lh.googleusercontent.com/EGemoI2N...
# 198693  https://play-lh.googleusercontent.com/EGemoI2N...
# 198692  https://play-lh.googleusercontent.com/EGemoI2N...
# 198691  https://play-lh.googleusercontent.com/EGemoI2N...
# 198690  https://play-lh.googleusercontent.com/EGemoI2N...
# 198689  https://play-lh.googleusercontent.com/EGemoI2N...
# 198688  https://play-lh.googleusercontent.com/EGemoI2N...
# 198687  https://play-lh.googleusercontent.com/EGemoI2N...
# 198686  https://play-lh.googleusercontent.com/EGemoI2N...
# 198685  https://play-lh.googleusercontent.com/EGemoI2N...
# 198684  https://play-lh.googleusercontent.com/EGemoI2N...
# 198683  https://play-lh.googleusercontent.com/EGemoI2N...
# 198682  https://play-lh.googleusercontent.com/EGemoI2N...
# 198681  https://play-lh.googleusercontent.com/EGemoI2N...
# 198680  https://play-lh.googleusercontent.com/EGemoI2N...
# 198679  https://play-lh.googleusercontent.com/EGemoI2N...
# 198678  https://play-lh.googleusercontent.com/EGemoI2N...
# 198677  https://play-lh.googleusercontent.com/EGemoI2N...
# 198676  https://play-lh.googleusercontent.com/EGemoI2N...
# 198675  https://play-lh.googleusercontent.com/EGemoI2N...
# 198674  https://play-lh.googleusercontent.com/a/AATXAJ...
# 198673  https://play-lh.googleusercontent.com/a-/AOh14...
# 198672  https://play-lh.googleusercontent.com/a/AATXAJ...
# 198671  https://play-lh.googleusercontent.com/a-/AOh14...
# 198670  https://play-lh.googleusercontent.com/a/AATXAJ...
# 198669  https://play-lh.googleusercontent.com/a-/AOh14...
# 198668  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                                   content  score  \
# 198697  Works fine.. I like the graphics and layout.. ...      5
# 198696  "Unknown error occurred" always popping up! Ne...      1
# 198695                           very convenient to use..      5
# 198694  It would really be great if you add "payable t...      4
# 198693  Its working fine with my motorola droid razr. ...      5
# 198692                              love the way you pay!      5
# 198691                                 Ill try if itworks      3
# 198690  I dont know about the others with low ratings,...      5
# 198689  For those QWERTY Android phones (Samsung Galax...      2
# 198688  Godd app! Hope u also create one for windows p...      4
# 198687  Would be nice if globe would allow us to conve...      1
# 198686                       Good app. Nice work Globe!!!      5
# 198685  Can use more functionality, but basic txns are...      4
# 198684  This is an excellent app. The UI is very simpl...      5
# 198683  Include options to buy credits in google play ...      4
# 198682  Finally! An app that eliminates the manual typ...      5
# 198681  If Gcash could b used to buy apps from GPlay, ...      3
# 198680  Could have been a 5 star, I have my Globe SIM ...      1
# 198679  Much easier transaction thank you Globe your s...      5
# 198678  Very few merchants are supported. The ones i n...      1
# 198677                              Terrible app, useless      1
# 198676  I can now finally enjoy shopping online using ...      5
# 198675    The QR code generator is amazing, super useful!      5
# 198674                                            Usefull      5
# 198673  This system is so strange! I am not filipino b...      1
# 198672  What im using is my Samsung galaxy mini for se...      2
# 198671                                  Very convenient!!      5
# 198670      Registered then send request forever in login      1
# 198669                         Makes transactions easier.      5
# 198668  Very accessible for the online buyers like me!...      4
#
#         thumbsUpCount reviewCreatedVersion                  at  \
# 198697              4              1.0.1.0 2012-03-26 13:49:59
# 198696              0              1.0.0.0 2012-03-26 18:49:57
# 198695              0              1.0.1.0 2012-05-08 11:32:34
# 198694              7              1.0.1.0 2012-05-31 21:53:30
# 198693              1              1.0.1.0 2012-06-20 21:38:43
# 198692              1              1.0.1.0 2012-07-02 22:10:54
# 198691              0                 None 2012-07-04 06:34:46
# 198690              7                 None 2012-08-10 09:51:20
# 198689              0                1.3.0 2012-08-17 15:29:38
# 198688              1                1.3.0 2012-08-19 07:44:10
# 198687              0                 None 2012-08-19 10:11:41
# 198686              1                 None 2012-08-21 19:07:55
# 198685              0                1.3.0 2012-08-21 23:58:06
# 198684              1                1.3.0 2012-08-22 21:28:16
# 198683              4                1.4.0 2012-08-29 13:58:43
# 198682              3                1.4.0 2012-09-12 11:09:00
# 198681              8                1.4.0 2012-09-23 22:11:36
# 198680              0                1.4.0 2012-09-25 11:09:30
# 198679              0                 None 2012-10-10 22:33:05
# 198678              1                1.4.1 2012-10-24 06:20:54
# 198677              0                 None 2012-10-27 01:23:53
# 198676              1                1.4.2 2012-11-20 21:00:21
# 198675              7                1.5.2 2012-12-07 08:53:12
# 198674              0                 None 2012-12-16 05:25:29
# 198673              0                 None 2012-12-18 11:58:51
# 198672              1                 None 2012-12-21 17:07:58
# 198671              0                 None 2012-12-28 00:26:14
# 198670              0                1.5.2 2013-01-08 09:00:10
# 198669              1                 None 2013-02-01 14:15:28
# 198668              0                 None 2013-02-26 11:48:56
#
#                                              replyContent           repliedAt  \
# 198697                                               None                 NaT
# 198696                                               None                 NaT
# 198695                                               None                 NaT
# 198694                                               None                 NaT
# 198693  Thank you for giving us a 5-star rating! Keep ... 2018-02-23 18:26:01
# 198692                                               None                 NaT
# 198691                                               None                 NaT
# 198690                                               None                 NaT
# 198689                                               None                 NaT
# 198688                                               None                 NaT
# 198687                                               None                 NaT
# 198686                                               None                 NaT
# 198685                                               None                 NaT
# 198684                                               None                 NaT
# 198683                                               None                 NaT
# 198682                                               None                 NaT
# 198681                                               None                 NaT
# 198680                                               None                 NaT
# 198679                                               None                 NaT
# 198678                                               None                 NaT
# 198677                                               None                 NaT
# 198676                                               None                 NaT
# 198675                                               None                 NaT
# 198674                                               None                 NaT
# 198673                                               None                 NaT
# 198672                                               None                 NaT
# 198671                                               None                 NaT
# 198670                                               None                 NaT
# 198669                                               None                 NaT
# 198668                                               None                 NaT
#
#        app_name                   app_id
# 198697    GCash  com.globe.gcash.android
# 198696    GCash  com.globe.gcash.android
# 198695    GCash  com.globe.gcash.android
# 198694    GCash  com.globe.gcash.android
# 198693    GCash  com.globe.gcash.android
# 198692    GCash  com.globe.gcash.android
# 198691    GCash  com.globe.gcash.android
# 198690    GCash  com.globe.gcash.android
# 198689    GCash  com.globe.gcash.android
# 198688    GCash  com.globe.gcash.android
# 198687    GCash  com.globe.gcash.android
# 198686    GCash  com.globe.gcash.android
# 198685    GCash  com.globe.gcash.android
# 198684    GCash  com.globe.gcash.android
# 198683    GCash  com.globe.gcash.android
# 198682    GCash  com.globe.gcash.android
# 198681    GCash  com.globe.gcash.android
# 198680    GCash  com.globe.gcash.android
# 198679    GCash  com.globe.gcash.android
# 198678    GCash  com.globe.gcash.android
# 198677    GCash  com.globe.gcash.android
# 198676    GCash  com.globe.gcash.android
# 198675    GCash  com.globe.gcash.android
# 198674    GCash  com.globe.gcash.android
# 198673    GCash  com.globe.gcash.android
# 198672    GCash  com.globe.gcash.android
# 198671    GCash  com.globe.gcash.android
# 198670    GCash  com.globe.gcash.android
# 198669    GCash  com.globe.gcash.android
# 198668    GCash  com.globe.gcash.android

# %%
review_df['reviewId'].nunique()
# Out:
# 198936
